# %% [markdown]
# # Neurone formel
# ### Modules necessaires :
# - NUMPY 1.16.3
# - MATPLOTLIB : 3.0.3
# - TENSORFLOW : 1.13.1

# %%
import numpy as np
from numpy import exp, array, random

import matplotlib.pyplot as plt
import tensorflow as tf

# %% [markdown]
# # Codons notre premier neurone formel "From Scratch"
#
# Voici un exemple de programme de neurone formel pour bien comprendre toute la mécanique de l'apprentissage à travers un exemple concret.
#
# ## Les données d'apprentissage
#
# La première chose nous allons créer nos données d'apprentissage et définir le taux d'apprentissage

# %%
#-------------------------------------
#    OBSERVATIONS ET PREDICTIONS
#-------------------------------------

observations_entrees = array([
                              [1, 0],
                              [1, 1],
                              [0, 1],
                              [0, 0]
                              ])

predictions = array([[0],[1], [0],[0]])

# %% [markdown]
# ## Définition des poids
#
# On génère les poids de façon aléatoire, dans l'intervalle de valeur [-1,1]

# %%
#--------------------------------------
#        PARAMETRAGE DU PERCEPTRON
#--------------------------------------

#Génération des poids dans l'interval [-1;1]

random.seed(1)
borneMin = -1
borneMax = 1

w11 = (borneMax-borneMin) * random.random() + borneMin
w21 = (borneMax-borneMin) * random.random() + borneMin

# %% [markdown]
# > Le biais qui aura pour valeur 1 et le poids sera égal à 0.

# %%
#Le biais
biais = 1
wb = 0

#Stockage des poids initiaux, uniquement pour affichage à la fin de l'apprentissage
poids = [w11,w21,wb]

# %% [markdown]
# ## Gestion des hyperparamètres

# %%
#Taux d'apprentissage
txApprentissage = 0.1

#Nombres d'epoques
#epochs = 300000
epochs = 3000

# %% [markdown]
# ## Codage de fonctions utiles
#
# Le code ci-dessous représente les différentes fonctions dont nous aurons besoin à savoir:
#
# - Le calcul de la somme pondérée
# - Le calcul de la fonction d'activation de type sigmoïde
# - Le calcul de l'erreur linéaire
# - Le calcul du gradient
# - Le calcul de la valeur d'ajustement du poids
# - Le calcul de la nouvelle valeur du poids
# - Le calcul de la fonction d'erreur moyenne quadratique (MSE)

# %%
#--------------------------------------
#       FONCTIONS UTILES
#--------------------------------------
import numpy as np


def somme_ponderee(X1,W11,X2,W21,B,WB):
    valeur_somme_ponderee = B * WB + (W11*X1 + W21 * X2)
    return valeur_somme_ponderee
 
def fonction_activation_sigmoide(valeur_somme_ponderee):
    valeur_somme_ponderee = 1 / (1 + exp(-valeur_somme_ponderee))
    return valeur_somme_ponderee

def fonction_activation_relu(valeur_somme_ponderee):
    valeur_somme_ponderee = (np.abs(valeur_somme_ponderee) + valeur_somme_ponderee) / 2.0   

    return valeur_somme_ponderee


def erreur_lineaire(valeur_attendue, valeur_predite):

    erreur = valeur_attendue - valeur_predite
    return erreur

def calcul_gradient(valeur_entree,prediction,erreur):
    # Gradient = - 1 * ERREUR * PREDICTION * (1-PREDICTION) * VALEUR_ENTREE
    valeur_gradient = -1 * erreur * prediction * (1-prediction) * valeur_entree
    
    return valeur_gradient

def calcul_valeur_ajustement(valeur_gradient, taux_apprentissage):
    # Valeur_ajustement_W11 = 0 .11386568 * 0.1
    valeur_ajustement = valeur_gradient * taux_apprentissage
    
    return valeur_ajustement
    

def calcul_nouveau_poids (valeur_poids, valeur_ajustement):
    # Nouveau_W11 = W11 – Valeur_ajustement_W11
    valeur_poids_nouveau = valeur_poids - valeur_ajustement 
    
    return valeur_poids_nouveau

def calcul_MSE(predictions_realisees, predictions_attendues):
  n = len(predictions_realisees)
  mse = 0
  e = 0
  for i in range(1,n):
    e = e + (predictions_attendues[i] - predictions_realisees[i])**2
  mse = e/n
  return mse

# %%
#--------------------------------------
#       GRAPHIQUE
#--------------------------------------

Graphique_MSE=[]

# %% [markdown]
# ## Apprentissage!
#
# Maintenant que nous disposons de tout ce dont nous avons besoin, nous pouvons passer à la phase d'apprentissage.
#
# Pour mener à bien cette phase d'apprentissage, nous allons
# * réaliser plusieurs époques (epoch), c'est-à-dire plusieurs passages complets de l'ensemble des observations contenues dans notre jeu de données à travers notre neurone formel.
# * réaliser pour chaque observation une prédiction et calculer l'erreur pour ensuite procéder à la mise à jour des poids synaptiques.

# %%
#--------------------------------------
#    APPRENTISSAGE
#--------------------------------------

for epoch in range(0,epochs):
    print("EPOCH ("+str(epoch)+"/"+str(epochs)+")")
    predictions_realisees_durant_epoch = [];
    predictions_attendues = [];
    numObservation = 0
    for observation in observations_entrees:
        print("Numéro Observation: ", numObservation)
        #Chargement de la couche d'entrée
        x1 = observation[0];
        x2 = observation[1];

        #Valeur de prédiction attendue
        valeur_attendue =predictions[numObservation];



        #Etape 1 : Calcul de la somme ponderee

        valeur_somme_ponderee = somme_ponderee(x1,w11,x2,w21,biais,wb)


        #Etape 2 : Application de la fonction d'activation
        valeur_predite = fonction_activation_sigmoide(valeur_somme_ponderee)


        #Etape 3 : Calcul de l'erreur
        valeur_erreur = erreur_lineaire(valeur_attendue, valeur_predite)
        

        #Mise à jour du poids 1
        #Calcul du gradient de la valeur d'ajustement et du nouveau poids
        gradient_W11 = calcul_gradient(x1,valeur_predite,valeur_erreur)
        
        # valeur_ajustement_W11 = 
        valeur_ajustement_W11= calcul_valeur_ajustement(gradient_W11,txApprentissage )
        w11 = calcul_nouveau_poids (w11, valeur_ajustement_W11)


        # Mise à jour du poids 2
        gradient_W21 = calcul_gradient(x2,valeur_predite,valeur_erreur)
        valeur_ajustement_W21 = calcul_valeur_ajustement(gradient_W21, txApprentissage)
        
        w21 = calcul_nouveau_poids (w21, valeur_ajustement_W21)


        # Mise à jour du poids du biais
        gradient_Wb = calcul_gradient(biais,valeur_predite,valeur_erreur)
        
        valeur_ajustement_Wb = calcul_valeur_ajustement(gradient_Wb,txApprentissage )
        wb = calcul_nouveau_poids (wb, valeur_ajustement_Wb)

        print("     EPOCH (" + str(epoch) + "/" + str(epochs) + ") -  Observation: " + str(numObservation+1) + "/" + str(len(observations_entrees)))

        #Stockage de la prediction realisee:
        predictions_realisees_durant_epoch.append(valeur_predite)
        predictions_attendues.append(predictions[numObservation][0])

        #Passage à l'observation suivante
        numObservation = numObservation+1

    MSE = calcul_MSE(predictions_realisees_durant_epoch, predictions)
    Graphique_MSE.append(MSE[0])
    print("MSE : "+str(MSE))
    print(valeur_erreur)
# Out:
# EPOCH (0/3000)
# Numéro Observation:  0
#      EPOCH (0/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (0/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (0/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (0/3000) -  Observation: 4/4
# MSE : [0.2026532]
# [-0.49621386]
# EPOCH (1/3000)
# Numéro Observation:  0
#      EPOCH (1/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (1/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (1/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (1/3000) -  Observation: 4/4
# MSE : [0.20048416]
# [-0.48945621]
# EPOCH (2/3000)
# Numéro Observation:  0
#      EPOCH (2/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (2/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (2/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (2/3000) -  Observation: 4/4
# MSE : [0.19841827]
# [-0.48287074]
# EPOCH (3/3000)
# Numéro Observation:  0
#      EPOCH (3/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (3/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (3/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (3/3000) -  Observation: 4/4
# MSE : [0.19644924]
# [-0.47645596]
# EPOCH (4/3000)
# Numéro Observation:  0
#      EPOCH (4/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (4/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (4/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (4/3000) -  Observation: 4/4
# MSE : [0.19457095]
# [-0.47020979]
# EPOCH (5/3000)
# Numéro Observation:  0
#      EPOCH (5/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (5/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (5/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (5/3000) -  Observation: 4/4
# MSE : [0.19277753]
# [-0.46412963]
# EPOCH (6/3000)
# Numéro Observation:  0
#      EPOCH (6/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (6/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (6/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (6/3000) -  Observation: 4/4
# MSE : [0.19106334]
# [-0.45821249]
# EPOCH (7/3000)
# Numéro Observation:  0
#      EPOCH (7/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (7/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (7/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (7/3000) -  Observation: 4/4
# MSE : [0.18942303]
# [-0.45245503]
# EPOCH (8/3000)
# Numéro Observation:  0
#      EPOCH (8/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (8/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (8/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (8/3000) -  Observation: 4/4
# MSE : [0.18785154]
# [-0.44685365]
# EPOCH (9/3000)
# Numéro Observation:  0
#      EPOCH (9/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (9/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (9/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (9/3000) -  Observation: 4/4
# MSE : [0.18634407]
# [-0.44140455]
# EPOCH (10/3000)
# Numéro Observation:  0
#      EPOCH (10/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (10/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (10/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (10/3000) -  Observation: 4/4
# MSE : [0.18489615]
# [-0.43610377]
# EPOCH (11/3000)
# Numéro Observation:  0
#      EPOCH (11/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (11/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (11/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (11/3000) -  Observation: 4/4
# MSE : [0.18350355]
# [-0.43094724]
# EPOCH (12/3000)
# Numéro Observation:  0
#      EPOCH (12/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (12/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (12/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (12/3000) -  Observation: 4/4
# MSE : [0.18216234]
# [-0.42593084]
# EPOCH (13/3000)
# Numéro Observation:  0
#      EPOCH (13/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (13/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (13/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (13/3000) -  Observation: 4/4
# MSE : [0.18086886]
# [-0.42105041]
# EPOCH (14/3000)
# Numéro Observation:  0
#      EPOCH (14/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (14/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (14/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (14/3000) -  Observation: 4/4
# MSE : [0.17961967]
# [-0.41630178]
# EPOCH (15/3000)
# Numéro Observation:  0
#      EPOCH (15/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (15/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (15/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (15/3000) -  Observation: 4/4
# MSE : [0.17841161]
# [-0.41168081]
# EPOCH (16/3000)
# Numéro Observation:  0
#      EPOCH (16/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (16/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (16/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (16/3000) -  Observation: 4/4
# MSE : [0.17724171]
# [-0.40718339]
# EPOCH (17/3000)
# Numéro Observation:  0
#      EPOCH (17/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (17/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (17/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (17/3000) -  Observation: 4/4
# MSE : [0.17610725]
# [-0.40280547]
# EPOCH (18/3000)
# Numéro Observation:  0
#      EPOCH (18/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (18/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (18/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (18/3000) -  Observation: 4/4
# MSE : [0.17500568]
# [-0.39854309]
# EPOCH (19/3000)
# Numéro Observation:  0
#      EPOCH (19/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (19/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (19/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (19/3000) -  Observation: 4/4
# MSE : [0.17393465]
# [-0.39439233]
# EPOCH (20/3000)
# Numéro Observation:  0
#      EPOCH (20/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (20/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (20/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (20/3000) -  Observation: 4/4
# MSE : [0.17289197]
# [-0.39034941]
# EPOCH (21/3000)
# Numéro Observation:  0
#      EPOCH (21/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (21/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (21/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (21/3000) -  Observation: 4/4
# MSE : [0.17187565]
# [-0.38641059]
# EPOCH (22/3000)
# Numéro Observation:  0
#      EPOCH (22/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (22/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (22/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (22/3000) -  Observation: 4/4
# MSE : [0.17088382]
# [-0.38257228]
# EPOCH (23/3000)
# Numéro Observation:  0
#      EPOCH (23/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (23/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (23/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (23/3000) -  Observation: 4/4
# MSE : [0.16991475]
# [-0.37883096]
# EPOCH (24/3000)
# Numéro Observation:  0
#      EPOCH (24/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (24/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (24/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (24/3000) -  Observation: 4/4
# MSE : [0.16896686]
# [-0.37518323]
# EPOCH (25/3000)
# Numéro Observation:  0
#      EPOCH (25/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (25/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (25/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (25/3000) -  Observation: 4/4
# MSE : [0.16803867]
# [-0.37162579]
# EPOCH (26/3000)
# Numéro Observation:  0
#      EPOCH (26/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (26/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (26/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (26/3000) -  Observation: 4/4
# MSE : [0.16712883]
# [-0.36815546]
# EPOCH (27/3000)
# Numéro Observation:  0
#      EPOCH (27/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (27/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (27/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (27/3000) -  Observation: 4/4
# MSE : [0.16623608]
# [-0.36476915]
# EPOCH (28/3000)
# Numéro Observation:  0
#      EPOCH (28/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (28/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (28/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (28/3000) -  Observation: 4/4
# MSE : [0.16535928]
# [-0.36146389]
# EPOCH (29/3000)
# Numéro Observation:  0
#      EPOCH (29/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (29/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (29/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (29/3000) -  Observation: 4/4
# MSE : [0.16449734]
# [-0.35823679]
# EPOCH (30/3000)
# Numéro Observation:  0
#      EPOCH (30/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (30/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (30/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (30/3000) -  Observation: 4/4
# MSE : [0.16364929]
# [-0.35508508]
# EPOCH (31/3000)
# Numéro Observation:  0
#      EPOCH (31/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (31/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (31/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (31/3000) -  Observation: 4/4
# MSE : [0.16281422]
# [-0.3520061]
# EPOCH (32/3000)
# Numéro Observation:  0
#      EPOCH (32/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (32/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (32/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (32/3000) -  Observation: 4/4
# MSE : [0.16199129]
# [-0.34899727]
# EPOCH (33/3000)
# Numéro Observation:  0
#      EPOCH (33/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (33/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (33/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (33/3000) -  Observation: 4/4
# MSE : [0.16117973]
# [-0.34605609]
# EPOCH (34/3000)
# Numéro Observation:  0
#      EPOCH (34/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (34/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (34/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (34/3000) -  Observation: 4/4
# MSE : [0.16037883]
# [-0.34318019]
# EPOCH (35/3000)
# Numéro Observation:  0
#      EPOCH (35/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (35/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (35/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (35/3000) -  Observation: 4/4
# MSE : [0.15958793]
# [-0.34036726]
# EPOCH (36/3000)
# Numéro Observation:  0
#      EPOCH (36/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (36/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (36/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (36/3000) -  Observation: 4/4
# MSE : [0.15880642]
# [-0.33761509]
# EPOCH (37/3000)
# Numéro Observation:  0
#      EPOCH (37/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (37/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (37/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (37/3000) -  Observation: 4/4
# MSE : [0.15803376]
# [-0.33492155]
# EPOCH (38/3000)
# Numéro Observation:  0
#      EPOCH (38/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (38/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (38/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (38/3000) -  Observation: 4/4
# MSE : [0.15726944]
# [-0.33228458]
# EPOCH (39/3000)
# Numéro Observation:  0
#      EPOCH (39/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (39/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (39/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (39/3000) -  Observation: 4/4
# MSE : [0.15651297]
# [-0.32970221]
# EPOCH (40/3000)
# Numéro Observation:  0
#      EPOCH (40/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (40/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (40/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (40/3000) -  Observation: 4/4
# MSE : [0.15576394]
# [-0.32717256]
# EPOCH (41/3000)
# Numéro Observation:  0
#      EPOCH (41/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (41/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (41/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (41/3000) -  Observation: 4/4
# MSE : [0.15502194]
# [-0.32469378]
# EPOCH (42/3000)
# Numéro Observation:  0
#      EPOCH (42/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (42/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (42/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (42/3000) -  Observation: 4/4
# MSE : [0.15428661]
# [-0.32226412]
# EPOCH (43/3000)
# Numéro Observation:  0
#      EPOCH (43/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (43/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (43/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (43/3000) -  Observation: 4/4
# MSE : [0.15355763]
# [-0.3198819]
# EPOCH (44/3000)
# Numéro Observation:  0
#      EPOCH (44/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (44/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (44/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (44/3000) -  Observation: 4/4
# MSE : [0.15283467]
# [-0.31754549]
# EPOCH (45/3000)
# Numéro Observation:  0
#      EPOCH (45/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (45/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (45/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (45/3000) -  Observation: 4/4
# MSE : [0.15211748]
# [-0.31525334]
# EPOCH (46/3000)
# Numéro Observation:  0
#      EPOCH (46/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (46/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (46/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (46/3000) -  Observation: 4/4
# MSE : [0.15140578]
# [-0.31300392]
# EPOCH (47/3000)
# Numéro Observation:  0
#      EPOCH (47/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (47/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (47/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (47/3000) -  Observation: 4/4
# MSE : [0.15069936]
# [-0.31079581]
# EPOCH (48/3000)
# Numéro Observation:  0
#      EPOCH (48/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (48/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (48/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (48/3000) -  Observation: 4/4
# MSE : [0.14999798]
# [-0.30862762]
# EPOCH (49/3000)
# Numéro Observation:  0
#      EPOCH (49/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (49/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (49/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (49/3000) -  Observation: 4/4
# MSE : [0.14930148]
# [-0.30649799]
# EPOCH (50/3000)
# Numéro Observation:  0
#      EPOCH (50/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (50/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (50/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (50/3000) -  Observation: 4/4
# MSE : [0.14860966]
# [-0.30440566]
# EPOCH (51/3000)
# Numéro Observation:  0
#      EPOCH (51/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (51/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (51/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (51/3000) -  Observation: 4/4
# MSE : [0.14792237]
# [-0.30234937]
# EPOCH (52/3000)
# Numéro Observation:  0
#      EPOCH (52/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (52/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (52/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (52/3000) -  Observation: 4/4
# MSE : [0.14723947]
# [-0.30032795]
# EPOCH (53/3000)
# Numéro Observation:  0
#      EPOCH (53/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (53/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (53/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (53/3000) -  Observation: 4/4
# MSE : [0.14656083]
# [-0.29834025]
# EPOCH (54/3000)
# Numéro Observation:  0
#      EPOCH (54/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (54/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (54/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (54/3000) -  Observation: 4/4
# MSE : [0.14588632]
# [-0.29638516]
# EPOCH (55/3000)
# Numéro Observation:  0
#      EPOCH (55/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (55/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (55/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (55/3000) -  Observation: 4/4
# MSE : [0.14521585]
# [-0.29446162]
# EPOCH (56/3000)
# Numéro Observation:  0
#      EPOCH (56/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (56/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (56/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (56/3000) -  Observation: 4/4
# MSE : [0.14454932]
# [-0.29256863]
# EPOCH (57/3000)
# Numéro Observation:  0
#      EPOCH (57/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (57/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (57/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (57/3000) -  Observation: 4/4
# MSE : [0.14388665]
# [-0.29070519]
# EPOCH (58/3000)
# Numéro Observation:  0
#      EPOCH (58/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (58/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (58/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (58/3000) -  Observation: 4/4
# MSE : [0.14322776]
# [-0.28887036]
# EPOCH (59/3000)
# Numéro Observation:  0
#      EPOCH (59/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (59/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (59/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (59/3000) -  Observation: 4/4
# MSE : [0.14257258]
# [-0.28706323]
# EPOCH (60/3000)
# Numéro Observation:  0
#      EPOCH (60/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (60/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (60/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (60/3000) -  Observation: 4/4
# MSE : [0.14192106]
# [-0.28528294]
# EPOCH (61/3000)
# Numéro Observation:  0
#      EPOCH (61/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (61/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (61/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (61/3000) -  Observation: 4/4
# MSE : [0.14127315]
# [-0.28352863]
# EPOCH (62/3000)
# Numéro Observation:  0
#      EPOCH (62/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (62/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (62/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (62/3000) -  Observation: 4/4
# MSE : [0.1406288]
# [-0.2817995]
# EPOCH (63/3000)
# Numéro Observation:  0
#      EPOCH (63/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (63/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (63/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (63/3000) -  Observation: 4/4
# MSE : [0.13998797]
# [-0.28009478]
# EPOCH (64/3000)
# Numéro Observation:  0
#      EPOCH (64/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (64/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (64/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (64/3000) -  Observation: 4/4
# MSE : [0.13935063]
# [-0.27841371]
# EPOCH (65/3000)
# Numéro Observation:  0
#      EPOCH (65/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (65/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (65/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (65/3000) -  Observation: 4/4
# MSE : [0.13871675]
# [-0.27675557]
# EPOCH (66/3000)
# Numéro Observation:  0
#      EPOCH (66/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (66/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (66/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (66/3000) -  Observation: 4/4
# MSE : [0.1380863]
# [-0.27511966]
# EPOCH (67/3000)
# Numéro Observation:  0
#      EPOCH (67/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (67/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (67/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (67/3000) -  Observation: 4/4
# MSE : [0.13745927]
# [-0.27350533]
# EPOCH (68/3000)
# Numéro Observation:  0
#      EPOCH (68/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (68/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (68/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (68/3000) -  Observation: 4/4
# MSE : [0.13683564]
# [-0.27191193]
# EPOCH (69/3000)
# Numéro Observation:  0
#      EPOCH (69/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (69/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (69/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (69/3000) -  Observation: 4/4
# MSE : [0.1362154]
# [-0.27033883]
# EPOCH (70/3000)
# Numéro Observation:  0
#      EPOCH (70/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (70/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (70/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (70/3000) -  Observation: 4/4
# MSE : [0.13559853]
# [-0.26878544]
# EPOCH (71/3000)
# Numéro Observation:  0
#      EPOCH (71/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (71/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (71/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (71/3000) -  Observation: 4/4
# MSE : [0.13498503]
# [-0.2672512]
# EPOCH (72/3000)
# Numéro Observation:  0
#      EPOCH (72/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (72/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (72/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (72/3000) -  Observation: 4/4
# MSE : [0.1343749]
# [-0.26573555]
# EPOCH (73/3000)
# Numéro Observation:  0
#      EPOCH (73/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (73/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (73/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (73/3000) -  Observation: 4/4
# MSE : [0.13376812]
# [-0.26423795]
# EPOCH (74/3000)
# Numéro Observation:  0
#      EPOCH (74/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (74/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (74/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (74/3000) -  Observation: 4/4
# MSE : [0.13316471]
# [-0.2627579]
# EPOCH (75/3000)
# Numéro Observation:  0
#      EPOCH (75/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (75/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (75/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (75/3000) -  Observation: 4/4
# MSE : [0.13256465]
# [-0.26129492]
# EPOCH (76/3000)
# Numéro Observation:  0
#      EPOCH (76/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (76/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (76/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (76/3000) -  Observation: 4/4
# MSE : [0.13196795]
# [-0.25984851]
# EPOCH (77/3000)
# Numéro Observation:  0
#      EPOCH (77/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (77/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (77/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (77/3000) -  Observation: 4/4
# MSE : [0.13137461]
# [-0.25841824]
# EPOCH (78/3000)
# Numéro Observation:  0
#      EPOCH (78/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (78/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (78/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (78/3000) -  Observation: 4/4
# MSE : [0.13078463]
# [-0.25700366]
# EPOCH (79/3000)
# Numéro Observation:  0
#      EPOCH (79/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (79/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (79/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (79/3000) -  Observation: 4/4
# MSE : [0.13019803]
# [-0.25560435]
# EPOCH (80/3000)
# Numéro Observation:  0
#      EPOCH (80/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (80/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (80/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (80/3000) -  Observation: 4/4
# MSE : [0.12961479]
# [-0.2542199]
# EPOCH (81/3000)
# Numéro Observation:  0
#      EPOCH (81/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (81/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (81/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (81/3000) -  Observation: 4/4
# MSE : [0.12903494]
# [-0.25284993]
# EPOCH (82/3000)
# Numéro Observation:  0
#      EPOCH (82/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (82/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (82/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (82/3000) -  Observation: 4/4
# MSE : [0.12845846]
# [-0.25149406]
# EPOCH (83/3000)
# Numéro Observation:  0
#      EPOCH (83/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (83/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (83/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (83/3000) -  Observation: 4/4
# MSE : [0.12788538]
# [-0.25015194]
# EPOCH (84/3000)
# Numéro Observation:  0
#      EPOCH (84/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (84/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (84/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (84/3000) -  Observation: 4/4
# MSE : [0.12731568]
# [-0.2488232]
# EPOCH (85/3000)
# Numéro Observation:  0
#      EPOCH (85/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (85/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (85/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (85/3000) -  Observation: 4/4
# MSE : [0.12674939]
# [-0.24750752]
# EPOCH (86/3000)
# Numéro Observation:  0
#      EPOCH (86/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (86/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (86/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (86/3000) -  Observation: 4/4
# MSE : [0.12618649]
# [-0.24620458]
# EPOCH (87/3000)
# Numéro Observation:  0
#      EPOCH (87/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (87/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (87/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (87/3000) -  Observation: 4/4
# MSE : [0.12562701]
# [-0.24491407]
# EPOCH (88/3000)
# Numéro Observation:  0
#      EPOCH (88/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (88/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (88/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (88/3000) -  Observation: 4/4
# MSE : [0.12507093]
# [-0.24363569]
# EPOCH (89/3000)
# Numéro Observation:  0
#      EPOCH (89/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (89/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (89/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (89/3000) -  Observation: 4/4
# MSE : [0.12451828]
# [-0.24236915]
# EPOCH (90/3000)
# Numéro Observation:  0
#      EPOCH (90/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (90/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (90/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (90/3000) -  Observation: 4/4
# MSE : [0.12396904]
# [-0.24111417]
# EPOCH (91/3000)
# Numéro Observation:  0
#      EPOCH (91/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (91/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (91/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (91/3000) -  Observation: 4/4
# MSE : [0.12342322]
# [-0.2398705]
# EPOCH (92/3000)
# Numéro Observation:  0
#      EPOCH (92/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (92/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (92/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (92/3000) -  Observation: 4/4
# MSE : [0.12288083]
# [-0.23863788]
# EPOCH (93/3000)
# Numéro Observation:  0
#      EPOCH (93/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (93/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (93/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (93/3000) -  Observation: 4/4
# MSE : [0.12234186]
# [-0.23741606]
# EPOCH (94/3000)
# Numéro Observation:  0
#      EPOCH (94/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (94/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (94/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (94/3000) -  Observation: 4/4
# MSE : [0.12180633]
# [-0.23620481]
# EPOCH (95/3000)
# Numéro Observation:  0
#      EPOCH (95/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (95/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (95/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (95/3000) -  Observation: 4/4
# MSE : [0.12127422]
# [-0.23500389]
# EPOCH (96/3000)
# Numéro Observation:  0
#      EPOCH (96/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (96/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (96/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (96/3000) -  Observation: 4/4
# MSE : [0.12074554]
# [-0.23381309]
# EPOCH (97/3000)
# Numéro Observation:  0
#      EPOCH (97/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (97/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (97/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (97/3000) -  Observation: 4/4
# MSE : [0.12022029]
# [-0.23263221]
# EPOCH (98/3000)
# Numéro Observation:  0
#      EPOCH (98/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (98/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (98/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (98/3000) -  Observation: 4/4
# MSE : [0.11969846]
# [-0.23146103]
# EPOCH (99/3000)
# Numéro Observation:  0
#      EPOCH (99/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (99/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (99/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (99/3000) -  Observation: 4/4
# MSE : [0.11918006]
# [-0.23029936]
# EPOCH (100/3000)
# Numéro Observation:  0
#      EPOCH (100/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (100/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (100/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (100/3000) -  Observation: 4/4
# MSE : [0.11866507]
# [-0.22914702]
# EPOCH (101/3000)
# Numéro Observation:  0
#      EPOCH (101/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (101/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (101/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (101/3000) -  Observation: 4/4
# MSE : [0.11815351]
# [-0.22800382]
# EPOCH (102/3000)
# Numéro Observation:  0
#      EPOCH (102/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (102/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (102/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (102/3000) -  Observation: 4/4
# MSE : [0.11764536]
# [-0.22686959]
# EPOCH (103/3000)
# Numéro Observation:  0
#      EPOCH (103/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (103/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (103/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (103/3000) -  Observation: 4/4
# MSE : [0.11714061]
# [-0.22574416]
# EPOCH (104/3000)
# Numéro Observation:  0
#      EPOCH (104/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (104/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (104/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (104/3000) -  Observation: 4/4
# MSE : [0.11663927]
# [-0.22462737]
# EPOCH (105/3000)
# Numéro Observation:  0
#      EPOCH (105/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (105/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (105/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (105/3000) -  Observation: 4/4
# MSE : [0.11614132]
# [-0.22351907]
# EPOCH (106/3000)
# Numéro Observation:  0
#      EPOCH (106/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (106/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (106/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (106/3000) -  Observation: 4/4
# MSE : [0.11564676]
# [-0.22241911]
# EPOCH (107/3000)
# Numéro Observation:  0
#      EPOCH (107/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (107/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (107/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (107/3000) -  Observation: 4/4
# MSE : [0.11515558]
# [-0.22132734]
# EPOCH (108/3000)
# Numéro Observation:  0
#      EPOCH (108/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (108/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (108/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (108/3000) -  Observation: 4/4
# MSE : [0.11466777]
# [-0.22024362]
# EPOCH (109/3000)
# Numéro Observation:  0
#      EPOCH (109/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (109/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (109/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (109/3000) -  Observation: 4/4
# MSE : [0.11418332]
# [-0.21916782]
# EPOCH (110/3000)
# Numéro Observation:  0
#      EPOCH (110/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (110/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (110/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (110/3000) -  Observation: 4/4
# MSE : [0.11370222]
# [-0.21809981]
# EPOCH (111/3000)
# Numéro Observation:  0
#      EPOCH (111/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (111/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (111/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (111/3000) -  Observation: 4/4
# MSE : [0.11322446]
# [-0.21703947]
# EPOCH (112/3000)
# Numéro Observation:  0
#      EPOCH (112/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (112/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (112/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (112/3000) -  Observation: 4/4
# MSE : [0.11275003]
# [-0.21598668]
# EPOCH (113/3000)
# Numéro Observation:  0
#      EPOCH (113/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (113/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (113/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (113/3000) -  Observation: 4/4
# MSE : [0.11227892]
# [-0.21494131]
# EPOCH (114/3000)
# Numéro Observation:  0
#      EPOCH (114/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (114/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (114/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (114/3000) -  Observation: 4/4
# MSE : [0.11181111]
# [-0.21390327]
# EPOCH (115/3000)
# Numéro Observation:  0
#      EPOCH (115/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (115/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (115/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (115/3000) -  Observation: 4/4
# MSE : [0.1113466]
# [-0.21287244]
# EPOCH (116/3000)
# Numéro Observation:  0
#      EPOCH (116/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (116/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (116/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (116/3000) -  Observation: 4/4
# MSE : [0.11088535]
# [-0.21184872]
# EPOCH (117/3000)
# Numéro Observation:  0
#      EPOCH (117/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (117/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (117/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (117/3000) -  Observation: 4/4
# MSE : [0.11042738]
# [-0.210832]
# EPOCH (118/3000)
# Numéro Observation:  0
#      EPOCH (118/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (118/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (118/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (118/3000) -  Observation: 4/4
# MSE : [0.10997265]
# [-0.2098222]
# EPOCH (119/3000)
# Numéro Observation:  0
#      EPOCH (119/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (119/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (119/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (119/3000) -  Observation: 4/4
# MSE : [0.10952115]
# [-0.20881921]
# EPOCH (120/3000)
# Numéro Observation:  0
#      EPOCH (120/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (120/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (120/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (120/3000) -  Observation: 4/4
# MSE : [0.10907287]
# [-0.20782295]
# EPOCH (121/3000)
# Numéro Observation:  0
#      EPOCH (121/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (121/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (121/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (121/3000) -  Observation: 4/4
# MSE : [0.10862779]
# [-0.20683333]
# EPOCH (122/3000)
# Numéro Observation:  0
#      EPOCH (122/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (122/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (122/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (122/3000) -  Observation: 4/4
# MSE : [0.10818589]
# [-0.20585026]
# EPOCH (123/3000)
# Numéro Observation:  0
#      EPOCH (123/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (123/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (123/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (123/3000) -  Observation: 4/4
# MSE : [0.10774716]
# [-0.20487367]
# EPOCH (124/3000)
# Numéro Observation:  0
#      EPOCH (124/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (124/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (124/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (124/3000) -  Observation: 4/4
# MSE : [0.10731158]
# [-0.20390347]
# EPOCH (125/3000)
# Numéro Observation:  0
#      EPOCH (125/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (125/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (125/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (125/3000) -  Observation: 4/4
# MSE : [0.10687912]
# [-0.20293959]
# EPOCH (126/3000)
# Numéro Observation:  0
#      EPOCH (126/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (126/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (126/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (126/3000) -  Observation: 4/4
# MSE : [0.10644978]
# [-0.20198195]
# EPOCH (127/3000)
# Numéro Observation:  0
#      EPOCH (127/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (127/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (127/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (127/3000) -  Observation: 4/4
# MSE : [0.10602354]
# [-0.20103049]
# EPOCH (128/3000)
# Numéro Observation:  0
#      EPOCH (128/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (128/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (128/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (128/3000) -  Observation: 4/4
# MSE : [0.10560037]
# [-0.20008512]
# EPOCH (129/3000)
# Numéro Observation:  0
#      EPOCH (129/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (129/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (129/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (129/3000) -  Observation: 4/4
# MSE : [0.10518025]
# [-0.19914579]
# EPOCH (130/3000)
# Numéro Observation:  0
#      EPOCH (130/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (130/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (130/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (130/3000) -  Observation: 4/4
# MSE : [0.10476317]
# [-0.19821243]
# EPOCH (131/3000)
# Numéro Observation:  0
#      EPOCH (131/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (131/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (131/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (131/3000) -  Observation: 4/4
# MSE : [0.10434911]
# [-0.19728497]
# EPOCH (132/3000)
# Numéro Observation:  0
#      EPOCH (132/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (132/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (132/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (132/3000) -  Observation: 4/4
# MSE : [0.10393804]
# [-0.19636335]
# EPOCH (133/3000)
# Numéro Observation:  0
#      EPOCH (133/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (133/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (133/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (133/3000) -  Observation: 4/4
# MSE : [0.10352995]
# [-0.19544752]
# EPOCH (134/3000)
# Numéro Observation:  0
#      EPOCH (134/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (134/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (134/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (134/3000) -  Observation: 4/4
# MSE : [0.10312481]
# [-0.19453741]
# EPOCH (135/3000)
# Numéro Observation:  0
#      EPOCH (135/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (135/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (135/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (135/3000) -  Observation: 4/4
# MSE : [0.10272261]
# [-0.19363296]
# EPOCH (136/3000)
# Numéro Observation:  0
#      EPOCH (136/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (136/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (136/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (136/3000) -  Observation: 4/4
# MSE : [0.10232332]
# [-0.19273413]
# EPOCH (137/3000)
# Numéro Observation:  0
#      EPOCH (137/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (137/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (137/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (137/3000) -  Observation: 4/4
# MSE : [0.10192693]
# [-0.19184085]
# EPOCH (138/3000)
# Numéro Observation:  0
#      EPOCH (138/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (138/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (138/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (138/3000) -  Observation: 4/4
# MSE : [0.1015334]
# [-0.19095308]
# EPOCH (139/3000)
# Numéro Observation:  0
#      EPOCH (139/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (139/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (139/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (139/3000) -  Observation: 4/4
# MSE : [0.10114273]
# [-0.19007077]
# EPOCH (140/3000)
# Numéro Observation:  0
#      EPOCH (140/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (140/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (140/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (140/3000) -  Observation: 4/4
# MSE : [0.10075488]
# [-0.18919385]
# EPOCH (141/3000)
# Numéro Observation:  0
#      EPOCH (141/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (141/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (141/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (141/3000) -  Observation: 4/4
# MSE : [0.10036984]
# [-0.1883223]
# EPOCH (142/3000)
# Numéro Observation:  0
#      EPOCH (142/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (142/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (142/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (142/3000) -  Observation: 4/4
# MSE : [0.09998759]
# [-0.18745604]
# EPOCH (143/3000)
# Numéro Observation:  0
#      EPOCH (143/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (143/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (143/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (143/3000) -  Observation: 4/4
# MSE : [0.0996081]
# [-0.18659505]
# EPOCH (144/3000)
# Numéro Observation:  0
#      EPOCH (144/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (144/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (144/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (144/3000) -  Observation: 4/4
# MSE : [0.09923136]
# [-0.18573928]
# EPOCH (145/3000)
# Numéro Observation:  0
#      EPOCH (145/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (145/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (145/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (145/3000) -  Observation: 4/4
# MSE : [0.09885733]
# [-0.18488868]
# EPOCH (146/3000)
# Numéro Observation:  0
#      EPOCH (146/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (146/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (146/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (146/3000) -  Observation: 4/4
# MSE : [0.098486]
# [-0.1840432]
# EPOCH (147/3000)
# Numéro Observation:  0
#      EPOCH (147/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (147/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (147/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (147/3000) -  Observation: 4/4
# MSE : [0.09811735]
# [-0.18320281]
# EPOCH (148/3000)
# Numéro Observation:  0
#      EPOCH (148/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (148/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (148/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (148/3000) -  Observation: 4/4
# MSE : [0.09775136]
# [-0.18236746]
# EPOCH (149/3000)
# Numéro Observation:  0
#      EPOCH (149/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (149/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (149/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (149/3000) -  Observation: 4/4
# MSE : [0.097388]
# [-0.18153711]
# EPOCH (150/3000)
# Numéro Observation:  0
#      EPOCH (150/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (150/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (150/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (150/3000) -  Observation: 4/4
# MSE : [0.09702725]
# [-0.18071173]
# EPOCH (151/3000)
# Numéro Observation:  0
#      EPOCH (151/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (151/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (151/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (151/3000) -  Observation: 4/4
# MSE : [0.09666909]
# [-0.17989126]
# EPOCH (152/3000)
# Numéro Observation:  0
#      EPOCH (152/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (152/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (152/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (152/3000) -  Observation: 4/4
# MSE : [0.09631349]
# [-0.17907569]
# EPOCH (153/3000)
# Numéro Observation:  0
#      EPOCH (153/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (153/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (153/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (153/3000) -  Observation: 4/4
# MSE : [0.09596045]
# [-0.17826495]
# EPOCH (154/3000)
# Numéro Observation:  0
#      EPOCH (154/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (154/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (154/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (154/3000) -  Observation: 4/4
# MSE : [0.09560993]
# [-0.17745903]
# EPOCH (155/3000)
# Numéro Observation:  0
#      EPOCH (155/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (155/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (155/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (155/3000) -  Observation: 4/4
# MSE : [0.09526191]
# [-0.17665788]
# EPOCH (156/3000)
# Numéro Observation:  0
#      EPOCH (156/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (156/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (156/3000) -  Observation: 3/4
# ...
# Numéro Observation:  1
#      EPOCH (2949/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (2949/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (2949/3000) -  Observation: 4/4
# MSE : [0.00728]
# [-0.00225573]
# EPOCH (2950/3000)
# Numéro Observation:  0
#      EPOCH (2950/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (2950/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (2950/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (2950/3000) -  Observation: 4/4
# MSE : [0.00727725]
# [-0.0022543]
# EPOCH (2951/3000)
# Numéro Observation:  0
#      EPOCH (2951/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (2951/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (2951/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (2951/3000) -  Observation: 4/4
# MSE : [0.0072745]
# [-0.00225286]
# EPOCH (2952/3000)
# Numéro Observation:  0
#      EPOCH (2952/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (2952/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (2952/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (2952/3000) -  Observation: 4/4
# MSE : [0.00727176]
# [-0.00225143]
# EPOCH (2953/3000)
# Numéro Observation:  0
#      EPOCH (2953/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (2953/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (2953/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (2953/3000) -  Observation: 4/4
# MSE : [0.00726901]
# [-0.00225]
# EPOCH (2954/3000)
# Numéro Observation:  0
#      EPOCH (2954/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (2954/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (2954/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (2954/3000) -  Observation: 4/4
# MSE : [0.00726627]
# [-0.00224858]
# EPOCH (2955/3000)
# Numéro Observation:  0
#      EPOCH (2955/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (2955/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (2955/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (2955/3000) -  Observation: 4/4
# MSE : [0.00726353]
# [-0.00224715]
# EPOCH (2956/3000)
# Numéro Observation:  0
#      EPOCH (2956/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (2956/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (2956/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (2956/3000) -  Observation: 4/4
# MSE : [0.00726079]
# [-0.00224573]
# EPOCH (2957/3000)
# Numéro Observation:  0
#      EPOCH (2957/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (2957/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (2957/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (2957/3000) -  Observation: 4/4
# MSE : [0.00725806]
# [-0.0022443]
# EPOCH (2958/3000)
# Numéro Observation:  0
#      EPOCH (2958/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (2958/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (2958/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (2958/3000) -  Observation: 4/4
# MSE : [0.00725532]
# [-0.00224288]
# EPOCH (2959/3000)
# Numéro Observation:  0
#      EPOCH (2959/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (2959/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (2959/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (2959/3000) -  Observation: 4/4
# MSE : [0.00725259]
# [-0.00224146]
# EPOCH (2960/3000)
# Numéro Observation:  0
#      EPOCH (2960/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (2960/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (2960/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (2960/3000) -  Observation: 4/4
# MSE : [0.00724986]
# [-0.00224004]
# EPOCH (2961/3000)
# Numéro Observation:  0
#      EPOCH (2961/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (2961/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (2961/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (2961/3000) -  Observation: 4/4
# MSE : [0.00724713]
# [-0.00223862]
# EPOCH (2962/3000)
# Numéro Observation:  0
#      EPOCH (2962/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (2962/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (2962/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (2962/3000) -  Observation: 4/4
# MSE : [0.00724441]
# [-0.00223721]
# EPOCH (2963/3000)
# Numéro Observation:  0
#      EPOCH (2963/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (2963/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (2963/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (2963/3000) -  Observation: 4/4
# MSE : [0.00724168]
# [-0.00223579]
# EPOCH (2964/3000)
# Numéro Observation:  0
#      EPOCH (2964/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (2964/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (2964/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (2964/3000) -  Observation: 4/4
# MSE : [0.00723896]
# [-0.00223438]
# EPOCH (2965/3000)
# Numéro Observation:  0
#      EPOCH (2965/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (2965/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (2965/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (2965/3000) -  Observation: 4/4
# MSE : [0.00723624]
# [-0.00223297]
# EPOCH (2966/3000)
# Numéro Observation:  0
#      EPOCH (2966/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (2966/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (2966/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (2966/3000) -  Observation: 4/4
# MSE : [0.00723352]
# [-0.00223155]
# EPOCH (2967/3000)
# Numéro Observation:  0
#      EPOCH (2967/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (2967/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (2967/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (2967/3000) -  Observation: 4/4
# MSE : [0.0072308]
# [-0.00223014]
# EPOCH (2968/3000)
# Numéro Observation:  0
#      EPOCH (2968/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (2968/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (2968/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (2968/3000) -  Observation: 4/4
# MSE : [0.00722809]
# [-0.00222874]
# EPOCH (2969/3000)
# Numéro Observation:  0
#      EPOCH (2969/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (2969/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (2969/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (2969/3000) -  Observation: 4/4
# MSE : [0.00722537]
# [-0.00222733]
# EPOCH (2970/3000)
# Numéro Observation:  0
#      EPOCH (2970/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (2970/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (2970/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (2970/3000) -  Observation: 4/4
# MSE : [0.00722266]
# [-0.00222592]
# EPOCH (2971/3000)
# Numéro Observation:  0
#      EPOCH (2971/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (2971/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (2971/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (2971/3000) -  Observation: 4/4
# MSE : [0.00721995]
# [-0.00222452]
# EPOCH (2972/3000)
# Numéro Observation:  0
#      EPOCH (2972/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (2972/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (2972/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (2972/3000) -  Observation: 4/4
# MSE : [0.00721725]
# [-0.00222312]
# EPOCH (2973/3000)
# Numéro Observation:  0
#      EPOCH (2973/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (2973/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (2973/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (2973/3000) -  Observation: 4/4
# MSE : [0.00721454]
# [-0.00222172]
# EPOCH (2974/3000)
# Numéro Observation:  0
#      EPOCH (2974/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (2974/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (2974/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (2974/3000) -  Observation: 4/4
# MSE : [0.00721184]
# [-0.00222032]
# EPOCH (2975/3000)
# Numéro Observation:  0
#      EPOCH (2975/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (2975/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (2975/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (2975/3000) -  Observation: 4/4
# MSE : [0.00720914]
# [-0.00221892]
# EPOCH (2976/3000)
# Numéro Observation:  0
#      EPOCH (2976/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (2976/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (2976/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (2976/3000) -  Observation: 4/4
# MSE : [0.00720644]
# [-0.00221752]
# EPOCH (2977/3000)
# Numéro Observation:  0
#      EPOCH (2977/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (2977/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (2977/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (2977/3000) -  Observation: 4/4
# MSE : [0.00720374]
# [-0.00221612]
# EPOCH (2978/3000)
# Numéro Observation:  0
#      EPOCH (2978/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (2978/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (2978/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (2978/3000) -  Observation: 4/4
# MSE : [0.00720104]
# [-0.00221473]
# EPOCH (2979/3000)
# Numéro Observation:  0
#      EPOCH (2979/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (2979/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (2979/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (2979/3000) -  Observation: 4/4
# MSE : [0.00719835]
# [-0.00221334]
# EPOCH (2980/3000)
# Numéro Observation:  0
#      EPOCH (2980/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (2980/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (2980/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (2980/3000) -  Observation: 4/4
# MSE : [0.00719566]
# [-0.00221195]
# EPOCH (2981/3000)
# Numéro Observation:  0
#      EPOCH (2981/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (2981/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (2981/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (2981/3000) -  Observation: 4/4
# MSE : [0.00719297]
# [-0.00221056]
# EPOCH (2982/3000)
# Numéro Observation:  0
#      EPOCH (2982/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (2982/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (2982/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (2982/3000) -  Observation: 4/4
# MSE : [0.00719028]
# [-0.00220917]
# EPOCH (2983/3000)
# Numéro Observation:  0
#      EPOCH (2983/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (2983/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (2983/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (2983/3000) -  Observation: 4/4
# MSE : [0.00718759]
# [-0.00220778]
# EPOCH (2984/3000)
# Numéro Observation:  0
#      EPOCH (2984/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (2984/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (2984/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (2984/3000) -  Observation: 4/4
# MSE : [0.00718491]
# [-0.00220639]
# EPOCH (2985/3000)
# Numéro Observation:  0
#      EPOCH (2985/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (2985/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (2985/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (2985/3000) -  Observation: 4/4
# MSE : [0.00718222]
# [-0.00220501]
# EPOCH (2986/3000)
# Numéro Observation:  0
#      EPOCH (2986/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (2986/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (2986/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (2986/3000) -  Observation: 4/4
# MSE : [0.00717954]
# [-0.00220362]
# EPOCH (2987/3000)
# Numéro Observation:  0
#      EPOCH (2987/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (2987/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (2987/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (2987/3000) -  Observation: 4/4
# MSE : [0.00717686]
# [-0.00220224]
# EPOCH (2988/3000)
# Numéro Observation:  0
#      EPOCH (2988/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (2988/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (2988/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (2988/3000) -  Observation: 4/4
# MSE : [0.00717419]
# [-0.00220086]
# EPOCH (2989/3000)
# Numéro Observation:  0
#      EPOCH (2989/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (2989/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (2989/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (2989/3000) -  Observation: 4/4
# MSE : [0.00717151]
# [-0.00219948]
# EPOCH (2990/3000)
# Numéro Observation:  0
#      EPOCH (2990/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (2990/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (2990/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (2990/3000) -  Observation: 4/4
# MSE : [0.00716884]
# [-0.0021981]
# EPOCH (2991/3000)
# Numéro Observation:  0
#      EPOCH (2991/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (2991/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (2991/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (2991/3000) -  Observation: 4/4
# MSE : [0.00716617]
# [-0.00219673]
# EPOCH (2992/3000)
# Numéro Observation:  0
#      EPOCH (2992/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (2992/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (2992/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (2992/3000) -  Observation: 4/4
# MSE : [0.0071635]
# [-0.00219535]
# EPOCH (2993/3000)
# Numéro Observation:  0
#      EPOCH (2993/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (2993/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (2993/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (2993/3000) -  Observation: 4/4
# MSE : [0.00716083]
# [-0.00219398]
# EPOCH (2994/3000)
# Numéro Observation:  0
#      EPOCH (2994/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (2994/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (2994/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (2994/3000) -  Observation: 4/4
# MSE : [0.00715816]
# [-0.0021926]
# EPOCH (2995/3000)
# Numéro Observation:  0
#      EPOCH (2995/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (2995/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (2995/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (2995/3000) -  Observation: 4/4
# MSE : [0.0071555]
# [-0.00219123]
# EPOCH (2996/3000)
# Numéro Observation:  0
#      EPOCH (2996/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (2996/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (2996/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (2996/3000) -  Observation: 4/4
# MSE : [0.00715284]
# [-0.00218986]
# EPOCH (2997/3000)
# Numéro Observation:  0
#      EPOCH (2997/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (2997/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (2997/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (2997/3000) -  Observation: 4/4
# MSE : [0.00715018]
# [-0.00218849]
# EPOCH (2998/3000)
# Numéro Observation:  0
#      EPOCH (2998/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (2998/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (2998/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (2998/3000) -  Observation: 4/4
# MSE : [0.00714752]
# [-0.00218712]
# EPOCH (2999/3000)
# Numéro Observation:  0
#      EPOCH (2999/3000) -  Observation: 1/4
# Numéro Observation:  1
#      EPOCH (2999/3000) -  Observation: 2/4
# Numéro Observation:  2
#      EPOCH (2999/3000) -  Observation: 3/4
# Numéro Observation:  3
#      EPOCH (2999/3000) -  Observation: 4/4
# MSE : [0.00714486]
# [-0.00218576]

# %% [markdown]
# Après exécution du code, on constate que la fonction d'erreur diminue au fil du temps, ce qui montre que notre neurone formel est bien en train d'apprendre.

# %%
import matplotlib.pyplot as plt
plt.plot(Graphique_MSE)
plt.ylabel('MSE')
plt.show()

# %% [markdown]
# > Mais avons-nous atteint le point de convergence?
#
# On voit bien d'après le graphe une diminution de l'erreur puis un léger palier pour ensuite reprendre la descente, mais cela ne nous indique pas si la convergence a été atteinte, on peut juste en déduire qu'avec une fonction d'erreur montrant un taux de 8% et vu l'allure de la courbe, nous pouvons encore espérer de meilleurs résultats.
#
# > Essayez de modifier le nombre d'epochs en le passant à 1000000 et à relancer l'apprentissage (attention, cela peut prendre du temps). Cette énorme valeur a volontairement été choisie pour vous montrer que notre algorithme continue toujours à améliorer son apprentissage, mais de façon très minime puisque la courbe de la fonction d'erreur semble se stabiliser.

# %% [markdown]
# ## Tests de prédictions
#
# Essayons à présent de réaliser quelques prédictions pour vérifier le bon fonctionnement de notre neurone artificiel.
#
# Dans un premier temps, nous allons changer le nombre d'epochs pour le mettre à 3000.
#
# Ajoutons quelques lignes qui vont nous permettre de connaître les poids issus de l'apprentissage :

# %%
print()
print()
print ("Apprentissage terminé !")
print ("Poid initiaux: " )
print ("W11 = "+str(poids[0]))
print ("W21 = "+str(poids[1]))
print ("Wb = "+str(poids[2]))

print ("Poid finaux: " )
print ("W11 = "+str(w11))
print ("W21 = "+str(w21))
print ("Wb = "+str(wb))
# Out:
# Apprentissage terminé !
# Poid initiaux:
# W11 = -0.165955990594852
# W21 = 0.4406489868843162
# Wb = 0
# Poid finaux:
# W11 = [4.01547358]
# W21 = [4.01313167]
# Wb = [-6.12360496]

# %% [markdown]
# Puis réalisons une prédiction :

# %%
print()
print("--------------------------")
print ("PREDICTION ")
print("--------------------------")
x1 = 1
x2 = 1
# Out:
# --------------------------
# PREDICTION
# --------------------------

# %%
#Etape 1 : Calcul de la somme ponderee
valeur_somme_ponderee = somme_ponderee(x1,w11,x2,w21,biais,wb)

# %%
#Etape 2 : Application de la fonction d'activation
valeur_predite = fonction_activation_sigmoide(valeur_somme_ponderee)
#valeur_predite = fonction_activation_relu(valeur_somme_ponderee)

# %%
print("Prediction du [" + str(x1) + "," + str(x2)  + "]")
print("Prediction = " + str(valeur_predite))
# Out:
# Prediction du [1,1]
# Prediction = [0.87045641]
